# %%
import pandas as pd 
data = pd.read_csv('SILKYSKY_DATA_CW2 (F).csv',encoding='latin1')
data
# Out:
#            Ref      id  Gender Satisfied  Age  Age Band   Type of Travel  \
# 0            0   70172    Male         Y   13  Under 18  Personal Travel
# 1            1    5047    Male         N   25  25 to 34  Business travel
# 2            2  110028  Female         Y   26  25 to 34  Business travel
# 3            3   24026  Female         Y   25  25 to 34  Business travel
# 4            4  119299    Male         Y   61  55 to 64  Business travel
# ...        ...     ...     ...       ...  ...       ...              ...
# 103899  103899   94171  Female         N   23  18 to 24  Business travel
# 103900  103900   73097    Male         Y   49  45 to 54  Business travel
# 103901  103901   68825    Male         N   30  25 to 34  Business travel
# 103902  103902   54173  Female         N   22  18 to 24  Business travel
# 103903  103903   62567    Male         Y   27  25 to 34  Business travel
#
#            Class  Flight Distance          Destination  ... Seat comfort  \
# ...

# %%
data.groupby('Gender')['Ref'].count().plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# 1) What percentage of passengers are satisfied vs. dissatisfied?

# %%
import matplotlib.pyplot as plt
data.columns
data['Satisfied']
total = data['Satisfied'].count()
satisfied =  data.groupby('Satisfied')['Ref'].count()[1]
not_satisfied =  data.groupby('Satisfied')['Ref'].count()[0]
plt.pie([satisfied ,not_satisfied],labels=["Satisfied", "Not Satisfied"],autopct='%1.1f%%')
# data.groupby('Satisfied')['Ref'].count().plot.bar()
data.groupby('Satisfied')['Ref'].count()
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2074201680.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   satisfied =  data.groupby('Satisfied')['Ref'].count()[1]
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2074201680.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   not_satisfied =  data.groupby('Satisfied')['Ref'].count()[0]
# Satisfied
# N    18984
# Y    84920
# Name: Ref, dtype: int64

# %%
data.columns
data.groupby('Gender')
satisfied=data[data['Satisfied']=='Y'].groupby('Gender')['Ref'].count()
not_satisfied=data[data['Satisfied']=='N'].groupby('Gender')['Ref'].count()
df_plot = pd.DataFrame({'Satisfied': satisfied, 'Unsatisfied': not_satisfied})
df_plot.plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %%
plt.figure(figsize=(15, 3)) 
plt.subplot(1,1,1)
plt.pie([satisfied[0],not_satisfied[0]],labels=["Satisfied", "Not Satisfied"],autopct='%1.1f%%',)
plt.title('Female')
plt.subplot(1,2,2)
plt.pie([satisfied[1],not_satisfied[1]],labels=["Satisfied", "Not Satisfied"],autopct='%1.1f%%',)
plt.title('Male')
plt.tight_layout()
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2062024610.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.pie([satisfied[0],not_satisfied[0]],labels=["Satisfied", "Not Satisfied"],autopct='%1.1f%%',)
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2062024610.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.pie([satisfied[1],not_satisfied[1]],labels=["Satisfied", "Not Satisfied"],autopct='%1.1f%%',)

# %%
data.columns
data['Type of Travel'].unique()
satisfiedd=data[data['Satisfied']=='Y'].groupby('Type of Travel')['Ref'].count()
not_satisfiedd=data[data['Satisfied']=='N'].groupby('Type of Travel')['Ref'].count()
# df=pd.DataFrame({'satisfied':satisfied,'not_satisfied':not_satisfied})
# df.plot.bar()
plt.figure(figsize=(10, 3)) 
plt.subplot(1,2,1)
plt.pie([satisfiedd[0],not_satisfiedd[0]],labels=['satisfied','not_satisfied'],autopct='%1.1f%%')
plt.title('Business Class')
plt.subplot(1,2,2)
plt.pie([satisfiedd[1],not_satisfiedd[1]],labels=['satisfied','not_satisfied'],autopct='%1.1f%%')
plt.title('Personal Class')
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2274135639.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.pie([satisfiedd[0],not_satisfiedd[0]],labels=['satisfied','not_satisfied'],autopct='%1.1f%%')
# C:\Users\tak\AppData\Local\Temp\ipykernel_18296\2274135639.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.pie([satisfiedd[1],not_satisfiedd[1]],labels=['satisfied','not_satisfied'],autopct='%1.1f%%')
# Text(0.5, 1.0, 'Personal Class')

# %%
data.groupby('Type of Travel').count()
# Out:
#                    Ref     id  Gender  Satisfied    Age  Age Band  Class  \
# Type of Travel
# Business travel  71655  71655   71655      71655  71655     71655  71655
# Personal Travel  32249  32249   32249      32249  32249     32249  32249
#
#                  Flight Distance  Destination  Continent  ...  Seat comfort  \
# Type of Travel                                            ...
# Business travel            71655        71655      71655  ...         71655
# Personal Travel            32249        32249      32249  ...         32249
#
#                  Inflight entertainment  On-board service  Leg room service  \
# Type of Travel
# Business travel                   71655             71655             71655
# Personal Travel                   32249             32249             32249
#
#                  Baggage handling  Checkin service  Inflight service  \
# Type of Travel
# Business travel             71655            71655             71655
# ...

# %% [markdown]
# 3) What age groups are most represented in the dataset?

# %%
import matplotlib.pyplot as plt
data['Age Band'].value_counts()
# data.columns
# data['Age Band'].isna().sum()
plt.figure(figsize=(10, 6)) 
plt.subplot(1,2,1)
data.groupby('Age Band')['Ref'].count().plot.bar()
band=data.groupby('Age Band')['Ref'].count()
# len(band)
plt.subplot(1,2,2)
labels=['18 to 24','25 to 34','35 to 44','45 to 54','55 to 64','65 or over','Under 18']
plt.pie([x for x in band],labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x167b4ae87a0>,
# ...
#  [Text(1.0297501328796927, 0.3868005478722277, '18 to 24'),
#   Text(0.2783456700693065, 1.0642009622029427, '25 to 34'),
#   Text(-0.9650031724563561, 0.5279856789243136, '35 to 44'),
#   Text(-0.7036521612059761, -0.8455020023809283, '45 to 54'),
#   Text(0.40683877684354963, -1.0219991240976896, '55 to 64'),
#   Text(0.8932458475827936, -0.6419593879491886, '65 or over'),
#   Text(1.068524581038137, -0.2612569993651345, 'Under 18')],
#  [Text(0.5616818906616505, 0.21098211702121508, '11.4%'),
#   Text(0.15182491094689443, 0.5804732521106959, '19.0%'),
#   Text(-0.526365366794376, 0.287992188504171, '23.2%'),
#   Text(-0.3838102697487142, -0.4611829103895972, '20.6%'),
#   Text(0.2219120600964816, -0.5574540676896488, '13.5%'),
#   Text(0.4872250077724328, -0.3501596661541029, '4.6%'),
#   Text(0.5828315896571655, -0.1425038178355279, '7.6%')])

# %% [markdown]
# 4)What are the most frequent destinations and continents?

# %%
print(data.columns)
data['Continent'].unique()
# data['Destination'].unique()
data.groupby('Continent')['Ref'].count().plot.bar()
data.groupby('Continent')['Ref'].count()
# data.groupby('Destination')['Ref'].count().plot.bar()
# Out:
# Index(['Ref', 'id', 'Gender', 'Satisfied', 'Age', 'Age Band', 'Type of Travel',
#        'Class', 'Flight Distance', 'Destination', 'Continent',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service', 'Cleanliness',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')
# Continent
# Africa                    2197
# Asia                     85789
# Europe                   14360
# Europe/Asia (Eurasia)       50
# North America             1478
# South America               30
# Name: Ref, dtype: int64
